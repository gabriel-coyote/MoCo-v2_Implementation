# %% [markdown]
# # **See Notebook Specs**

# %%
from psutil import *
cpu_count()

# !cat /proc/cpuinfo
# Out:
# 60

# %%
from psutil import *
print("\n");
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')


gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Your runtime has 253.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# Not connected to a GPU

# %% [markdown]
# # **Getting MoCo-v2 Setup**

# %%
# Cloning Alex's MoCo-v2 github into this notebook
# !git clone https://github.com/AlexZaikin94/MoCo-v2.git
# Out:
# Cloning into 'MoCo-v2'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 47 (delta 11), reused 44 (delta 8), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
# Installing Anaconda into this Notebook
# Following code works only on Google Colab Notebooks
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda --version
# Out:
# conda 4.9.2

# %%
# !ls
# Out:
# condacolab_install.log	MoCo-v2  sample_data

# %%
# %cd MoCo-v2
# Out:
# /content/MoCo-v2

# %%
# !ls
# Out:
# config.py	  evaluate.py  main_moco.py  run_download.sh
# download_data.py  LICENSE      models	     run_evaluate.sh
# environment.yml   logs	       README.md     run_moco.sh
# evaluate.ipynb	  main_clf.py  run_clf.sh    src

# %%
# Install pytorch into this Notebook
# !conda install pytorch torchvision torchaudio -c pytorch
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     blas-2.106                 |              mkl          12 KB  conda-forge
#     ca-certificates-2021.10.8  |       ha878542_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_1         145 KB  conda-forge
#     conda-4.11.0               |   py37h89c1867_1         983 KB  conda-forge
#     cudatoolkit-11.1.1         |       h6406543_8        1.20 GB  conda-forge
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     jpeg-9e                    |       h7f98852_0         269 KB  conda-forge
#     lame-3.100                 |    h7f98852_1001         496 KB  conda-forge
#     libblas-3.9.0              |            6_mkl          11 KB  conda-forge
#     libcblas-3.9.0             |            6_mkl          11 KB  conda-forge
#     libgcc-ng-11.2.0           |      h1d223b6_13         906 KB  conda-forge
#     libgfortran-ng-11.2.0      |      h69a702a_13          19 KB  conda-forge
#     libgfortran5-11.2.0        |      h5c6108e_13         1.7 MB  conda-forge
#     liblapack-3.9.0            |            6_mkl          11 KB  conda-forge
#     liblapacke-3.9.0           |            6_mkl          11 KB  conda-forge
#     libpng-1.6.37              |       h21135ba_2         306 KB  conda-forge
#     libtiff-4.0.10             |    hc3755c2_1005         602 KB  conda-forge
#     libuv-1.43.0               |       h7f98852_0         1.0 MB  conda-forge
#     libzlib-1.2.11             |    h36c2ea0_1013          59 KB  conda-forge
#     llvm-openmp-13.0.1         |       he0ac6c6_1         3.4 MB  conda-forge
#     mkl-2020.4                 |     h726a3e6_304       215.6 MB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     numpy-1.20.3               |   py37h038b26d_1         5.7 MB  conda-forge
#     olefile-0.46               |     pyh9f0ad1d_1          32 KB  conda-forge
#     openh264-2.1.1             |       h780b84a_0         1.5 MB  conda-forge
#     openssl-1.1.1l             |       h7f98852_0         2.1 MB  conda-forge
#     pillow-6.2.1               |   py37h6b7be26_0         637 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     pytorch-1.10.2             |py3.7_cuda11.1_cudnn8.0.5_0        1.53 GB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-0.10.2          |       py37_cu111         4.5 MB  pytorch
#     torchvision-0.11.3         |       py37_cu111        30.5 MB  pytorch
#     typing_extensions-4.1.1    |     pyha770c72_0          29 KB  conda-forge
#     zlib-1.2.11                |    h36c2ea0_1013          86 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        3.02 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               conda-forge/linux-64::blas-2.106-mkl
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.1.1-h6406543_8
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   jpeg               conda-forge/linux-64::jpeg-9e-h7f98852_0
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   libblas            conda-forge/linux-64::libblas-3.9.0-6_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-6_mkl
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-11.2.0-h69a702a_13
#   libgfortran5       conda-forge/linux-64::libgfortran5-11.2.0-h5c6108e_13
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-6_mkl
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-6_mkl
#   libpng             conda-forge/linux-64::libpng-1.6.37-h21135ba_2
#   libtiff            conda-forge/linux-64::libtiff-4.0.10-hc3755c2_1005
#   libuv              conda-forge/linux-64::libuv-1.43.0-h7f98852_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.11-h36c2ea0_1013
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-13.0.1-he0ac6c6_1
#   mkl                conda-forge/linux-64::mkl-2020.4-h726a3e6_304
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   numpy              conda-forge/linux-64::numpy-1.20.3-py37h038b26d_1
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   pillow             conda-forge/linux-64::pillow-6.2.1-py37h6b7be26_0
#   pytorch            pytorch/linux-64::pytorch-1.10.2-py3.7_cuda11.1_cudnn8.0.5_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/linux-64::torchaudio-0.10.2-py37_cu111
#   torchvision        pytorch/linux-64::torchvision-0.11.3-py37_cu111
#   typing_extensions  conda-forge/noarch::typing_extensions-4.1.1-pyha770c72_0
#
# The following packages will be REMOVED:
#
#   libgomp-9.3.0-h2828fa1_18
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2020.12.5-ha878542_0 --> 2021.10.8-ha878542_0
#   certifi                          2020.12.5-py37h89c1867_1 --> 2021.10.8-py37h89c1867_1
#   conda                                4.9.2-py37h89c1867_0 --> 4.11.0-py37h89c1867_1
#   libgcc-ng                               9.3.0-h2828fa1_18 --> 11.2.0-h1d223b6_13
#   openssl                                 1.1.1j-h7f98852_0 --> 1.1.1l-h7f98852_0
#   python_abi                                    3.7-1_cp37m --> 3.7-2_cp37m
#   zlib                                 1.2.11-h516909a_1010 --> 1.2.11-h36c2ea0_1013
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-1_llvm
#
#
#
# Downloading and Extracting Packages
# blas-2.106           | 12 KB     | : 100% 1.0/1 [00:00<00:00,  9.94it/s]
# _openmp_mutex-4.5    | 5 KB      | : 100% 1.0/1 [00:00<00:00, 23.20it/s]
# certifi-2021.10.8    | 145 KB    | : 100% 1.0/1 [00:00<00:00, 12.39it/s]
# llvm-openmp-13.0.1   | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  2.25it/s]
# lame-3.100           | 496 KB    | : 100% 1.0/1 [00:00<00:00, 10.25it/s]
# typing_extensions-4. | 29 KB     | : 100% 1.0/1 [00:00<00:00, 25.48it/s]
# pytorch-mutex-1.0    | 3 KB      | : 100% 1.0/1 [00:00<00:00,  2.87it/s]
# olefile-0.46         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 25.74it/s]
# zlib-1.2.11          | 86 KB     | : 100% 1.0/1 [00:00<00:00, 21.17it/s]
# pytorch-1.10.2       | 1.53 GB   | : 100% 1.0/1 [03:17<00:00, 197.12s/it]
# libblas-3.9.0        | 11 KB     | : 100% 1.0/1 [00:00<00:00, 19.33it/s]
# liblapack-3.9.0      | 11 KB     | : 100% 1.0/1 [00:00<00:00, 22.01it/s]
# numpy-1.20.3         | 5.7 MB    | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# libcblas-3.9.0       | 11 KB     | : 100% 1.0/1 [00:00<00:00, 28.86it/s]
# nettle-3.6           | 6.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
# libpng-1.6.37        | 306 KB    | : 100% 1.0/1 [00:00<00:00, 10.10it/s]
# freetype-2.10.4      | 890 KB    | : 100% 1.0/1 [00:00<00:00,  7.12it/s]
# libgfortran-ng-11.2. | 19 KB     | : 100% 1.0/1 [00:00<00:00, 26.19it/s]
# openssl-1.1.1l       | 2.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.74it/s]
# mkl-2020.4           | 215.6 MB  | : 100% 1.0/1 [00:29<00:00, 29.07s/it]
# gmp-6.2.1            | 806 KB    | : 100% 1.0/1 [00:00<00:00,  6.54it/s]
# torchvision-0.11.3   | 30.5 MB   | : 100% 1.0/1 [00:04<00:00,  4.02s/it]
# pillow-6.2.1         | 637 KB    | : 100% 1.0/1 [00:00<00:00,  8.34it/s]
# gnutls-3.6.13        | 2.0 MB    | : 100% 1.0/1 [00:00<00:00,  2.68it/s]
# cudatoolkit-11.1.1   | 1.20 GB   | : 100% 1.0/1 [02:03<00:00, 123.38s/it]
# libuv-1.43.0         | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  6.37it/s]
# ca-certificates-2021 | 139 KB    | : 100% 1.0/1 [00:00<00:00, 21.85it/s]
# liblapacke-3.9.0     | 11 KB     | : 100% 1.0/1 [00:00<00:00, 29.53it/s]
# libgcc-ng-11.2.0     | 906 KB    | : 100% 1.0/1 [00:00<00:00,  7.73it/s]
# openh264-2.1.1       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  4.68it/s]
# conda-4.11.0         | 983 KB    | : 100% 1.0/1 [00:00<00:00,  5.19it/s]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00, 27.48it/s]
# ffmpeg-4.3           | 9.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
# torchaudio-0.10.2    | 4.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
# libzlib-1.2.11       | 59 KB     | : 100% 1.0/1 [00:00<00:00, 24.84it/s]
# libtiff-4.0.10       | 602 KB    | : 100% 1.0/1 [00:00<00:00,  8.89it/s]
# libgfortran5-11.2.0  | 1.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.75it/s]
# jpeg-9e              | 269 KB    | : 100% 1.0/1 [00:00<00:00, 14.05it/s]
# done
# done
# \ By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done

# %% [markdown]
# # **Install requirements for enironment setup**

# %%
# !ls
# Out:
# config.py	  evaluate.py  main_moco.py  run_download.sh
# download_data.py  LICENSE      models	     run_evaluate.sh
# environment.yml   logs	       README.md     run_moco.sh
# evaluate.ipynb	  main_clf.py  run_clf.sh    src

# %%
# Following Alex's GitHub Guide
# [Step 1.] Install requirements for environment steup
# !ls
# !conda env create -f environment.yml
# Out:
# config.py	  evaluate.py  main_moco.py  run_download.sh
# download_data.py  LICENSE      models	     run_evaluate.sh
# environment.yml   logs	       README.md     run_moco.sh
# evaluate.ipynb	  main_clf.py  run_clf.sh    src
# done
# done
#
# Downloading and Extracting Packages
# nettle-3.7.2         | 811 KB    | : 100% 1.0/1 [00:00<00:00,  4.73it/s]
# ncurses-6.2          | 817 KB    | : 100% 1.0/1 [00:00<00:00,  4.48it/s]
# pexpect-4.8.0        | 53 KB     | : 100% 1.0/1 [00:00<00:00, 10.84it/s]
# jpeg-9b              | 214 KB    | : 100% 1.0/1 [00:00<00:00,  8.95it/s]
# openssl-1.1.1k       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  5.48it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 10.60it/s]
# numpy-base-1.20.2    | 4.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.14it/s]
# pygments-2.9.0       | 721 KB    | : 100% 1.0/1 [00:00<00:00,  6.49it/s]
# ipykernel-5.3.4      | 183 KB    | : 100% 1.0/1 [00:00<00:00,  9.77it/s]
# torchaudio-0.8.1     | 4.4 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
# typing_extensions-3. | 25 KB     | : 100% 1.0/1 [00:00<00:00, 36.14it/s]
# gmp-6.2.1            | 539 KB    | : 100% 1.0/1 [00:00<00:00,  8.98it/s]
# lame-3.100           | 323 KB    | : 100% 1.0/1 [00:00<00:00, 10.16it/s]
# libsodium-1.0.18     | 244 KB    | : 100% 1.0/1 [00:00<00:00, 10.26it/s]
# decorator-5.0.9      | 12 KB     | : 100% 1.0/1 [00:00<00:00, 11.38it/s]
# jupyter_core-4.7.1   | 68 KB     | : 100% 1.0/1 [00:00<00:00,  9.94it/s]
# mkl-2021.2.0         | 144.3 MB  | : 100% 1.0/1 [00:03<00:00,  3.40s/it]
# backcall-0.2.0       | 13 KB     | : 100% 1.0/1 [00:00<00:00, 39.49it/s]
# numpy-1.20.2         | 23 KB     | : 100% 1.0/1 [00:00<00:00, 10.59it/s]
# pytorch-1.8.1        | 673.4 MB  | : 100% 1.0/1 [01:18<00:00, 78.74s/it]
# gnutls-3.6.15        | 1.0 MB    | : 100% 1.0/1 [00:00<00:00,  7.70it/s]
# ld_impl_linux-64-2.3 | 568 KB    | : 100% 1.0/1 [00:00<00:00,  9.40it/s]
# ipython_genutils-0.2 | 27 KB     | : 100% 1.0/1 [00:00<00:00,  9.50it/s]
# wcwidth-0.2.5        | 29 KB     | : 100% 1.0/1 [00:00<00:00, 10.42it/s]
# ca-certificates-2021 | 114 KB    | : 100% 1.0/1 [00:00<00:00,  7.93it/s]
# zlib-1.2.11          | 103 KB    | : 100% 1.0/1 [00:00<00:00, 10.07it/s]
# traitlets-5.0.5      | 81 KB     | : 100% 1.0/1 [00:00<00:00, 24.53it/s]
# jedi-0.17.0          | 780 KB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
# libuv-1.40.0         | 736 KB    | : 100% 1.0/1 [00:00<00:00,  9.16it/s]
# pickleshare-0.7.5    | 13 KB     | : 100% 1.0/1 [00:00<00:00, 10.29it/s]
# libtasn1-4.16.0      | 58 KB     | : 100% 1.0/1 [00:00<00:00, 10.19it/s]
# intel-openmp-2021.2. | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  4.99it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00,  9.81it/s]
# freetype-2.10.4      | 596 KB    | : 100% 1.0/1 [00:00<00:00,  8.83it/s]
# prompt-toolkit-3.0.1 | 256 KB    | : 100% 1.0/1 [00:00<00:00,  8.74it/s]
# python-3.8.10        | 50.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
# ptyprocess-0.7.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00, 10.16it/s]
# lcms2-2.12           | 312 KB    | : 100% 1.0/1 [00:00<00:00,  9.88it/s]
# mkl-service-2.3.0    | 57 KB     | : 100% 1.0/1 [00:00<00:00,  7.30it/s]
# cudatoolkit-10.2.89  | 365.1 MB  | : 100% 1.0/1 [00:05<00:00,  5.14s/it]
# zstd-1.4.9           | 480 KB    | : 100% 1.0/1 [00:00<00:00,  9.64it/s]
# tornado-6.1          | 588 KB    | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00, 10.60it/s]
# setuptools-52.0.0    | 714 KB    | : 100% 1.0/1 [00:00<00:00,  7.91it/s]
# zeromq-4.3.4         | 331 KB    | : 100% 1.0/1 [00:00<00:00,  9.37it/s]
# libgcc-ng-9.1.0      | 5.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.72it/s]
# xz-5.2.5             | 341 KB    | : 100% 1.0/1 [00:00<00:00,  9.24it/s]
# mkl_random-1.2.1     | 305 KB    | : 100% 1.0/1 [00:00<00:00,  6.20it/s]
# parso-0.8.2          | 69 KB     | : 100% 1.0/1 [00:00<00:00, 10.14it/s]
# ipython-7.22.0       | 982 KB    | : 100% 1.0/1 [00:00<00:00,  6.85it/s]
# lz4-c-1.9.3          | 186 KB    | : 100% 1.0/1 [00:00<00:00,  9.26it/s]
# libtiff-4.1.0        | 449 KB    | : 100% 1.0/1 [00:00<00:00,  8.73it/s]
# torchvision-0.9.1    | 25.7 MB   | : 100% 1.0/1 [00:03<00:00,  3.60s/it]
# jupyter_client-6.1.1 | 88 KB     | : 100% 1.0/1 [00:00<00:00,  9.25it/s]
# certifi-2020.12.5    | 141 KB    | : 100% 1.0/1 [00:00<00:00, 10.25it/s]
# openh264-2.1.0       | 722 KB    | : 100% 1.0/1 [00:00<00:00,  9.04it/s]
# ninja-1.10.2         | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  8.16it/s]
# libiconv-1.15        | 721 KB    | : 100% 1.0/1 [00:00<00:00,  7.49it/s]
# libidn2-2.3.1        | 85 KB     | : 100% 1.0/1 [00:00<00:00,  8.08it/s]
# libstdcxx-ng-9.1.0   | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  6.20it/s]
# pyzmq-20.0.0         | 447 KB    | : 100% 1.0/1 [00:00<00:00,  8.54it/s]
# libunistring-0.9.10  | 536 KB    | : 100% 1.0/1 [00:00<00:00,  9.58it/s]
# bzip2-1.0.8          | 78 KB     | : 100% 1.0/1 [00:00<00:00, 10.36it/s]
# six-1.15.0           | 27 KB     | : 100% 1.0/1 [00:00<00:00, 10.68it/s]
# pillow-8.2.0         | 628 KB    | : 100% 1.0/1 [00:00<00:00,  8.60it/s]
# olefile-0.46         | 33 KB     | : 100% 1.0/1 [00:00<00:00, 10.39it/s]
# _libgcc_mutex-0.1    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 10.58it/s]
# mkl_fft-1.3.0        | 180 KB    | : 100% 1.0/1 [00:00<00:00,  9.78it/s]
# readline-8.1         | 362 KB    | : 100% 1.0/1 [00:00<00:00,  9.36it/s]
# wheel-0.36.2         | 33 KB     | : 100% 1.0/1 [00:00<00:00, 10.49it/s]
# tk-8.6.10            | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
# pip-21.1.1           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.78it/s]
# sqlite-3.35.4        | 981 KB    | : 100% 1.0/1 [00:00<00:00,  7.29it/s]
# python-dateutil-2.8. | 221 KB    | : 100% 1.0/1 [00:00<00:00, 15.09it/s]
# done
# done
# done
# \ Ran pip subprocess with arguments:
# ['/usr/local/envs/hw1/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/MoCo-v2/condaenv.4c0oygt2.requirements.txt']
# Pip subprocess output:
# Collecting argon2-cffi==20.1.0
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting async-generator==1.10
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting attrs==21.2.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting bleach==3.3.0
#   Downloading bleach-3.3.0-py2.py3-none-any.whl (283 kB)
# Collecting cffi==1.14.5
#   Downloading cffi-1.14.5-cp38-cp38-manylinux1_x86_64.whl (411 kB)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting defusedxml==0.7.1
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting dill==0.3.3
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting entrypoints==0.3
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting h5py==3.2.1
#   Downloading h5py-3.2.1-cp38-cp38-manylinux1_x86_64.whl (4.5 MB)
# Collecting ipywidgets==7.6.3
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting jinja2==3.0.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting joblib==1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting jupyterlab-pygments==0.1.2
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting jupyterlab-widgets==1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Collecting kiwisolver==1.3.1
#   Downloading kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
# Collecting markupsafe==2.0.1
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (30 kB)
# Collecting matplotlib==3.4.2
#   Downloading matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
# Collecting mistune==0.8.4
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting nbclient==0.5.3
#   Downloading nbclient-0.5.3-py3-none-any.whl (82 kB)
# Collecting nbconvert==6.0.7
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting nbformat==5.1.3
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting nest-asyncio==1.5.1
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting notebook==6.4.0
#   Downloading notebook-6.4.0-py3-none-any.whl (9.5 MB)
# Collecting packaging==20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4-cp38-cp38-manylinux1_x86_64.whl (9.7 MB)
# Collecting pandocfilters==1.4.3
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting prometheus-client==0.10.1
#   Downloading prometheus_client-0.10.1-py2.py3-none-any.whl (55 kB)
# Collecting pycparser==2.20
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pyrsistent==0.17.3
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
# Collecting pytz==2021.1
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# Collecting scipy==1.6.3
#   Downloading scipy-1.6.3-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# Collecting send2trash==1.5.0
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting terminado==0.10.0
#   Downloading terminado-0.10.0-py3-none-any.whl (14 kB)
# Collecting testpath==0.5.0
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
# Collecting threadpoolctl==2.1.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting tqdm==4.61.0
#   Downloading tqdm-4.61.0-py2.py3-none-any.whl (75 kB)
# Collecting webencodings==0.5.1
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting widgetsnbextension==3.5.1
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: six in /usr/local/envs/hw1/lib/python3.8/site-packages (from argon2-cffi==20.1.0->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/envs/hw1/lib/python3.8/site-packages (from h5py==3.2.1->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 10)) (1.20.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (7.22.0)
# Requirement already satisfied: setuptools in /usr/local/envs/hw1/lib/python3.8/site-packages (from jsonschema==3.2.0->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 14)) (52.0.0.post20210125)
# Requirement already satisfied: pygments<3,>=2.4.1 in /usr/local/envs/hw1/lib/python3.8/site-packages (from jupyterlab-pygments==0.1.2->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 15)) (2.9.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/hw1/lib/python3.8/site-packages (from matplotlib==3.4.2->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 19)) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/envs/hw1/lib/python3.8/site-packages (from matplotlib==3.4.2->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 19)) (8.2.0)
# Requirement already satisfied: jupyter-client>=6.1.5 in /usr/local/envs/hw1/lib/python3.8/site-packages (from nbclient==0.5.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 21)) (6.1.12)
# Requirement already satisfied: jupyter-core in /usr/local/envs/hw1/lib/python3.8/site-packages (from nbconvert==6.0.7->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 22)) (4.7.1)
# Requirement already satisfied: ipython-genutils in /usr/local/envs/hw1/lib/python3.8/site-packages (from nbformat==5.1.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 23)) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/envs/hw1/lib/python3.8/site-packages (from notebook==6.4.0->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 25)) (20.0.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/envs/hw1/lib/python3.8/site-packages (from notebook==6.4.0->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 25)) (6.1)
# Requirement already satisfied: ptyprocess in /usr/local/envs/hw1/lib/python3.8/site-packages (from terminado==0.10.0->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 38)) (0.7.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (0.17.0)
# Requirement already satisfied: backcall in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (3.0.17)
# Requirement already satisfied: decorator in /usr/local/envs/hw1/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (5.0.9)
# Requirement already satisfied: parso>=0.7.0 in /usr/local/envs/hw1/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (0.8.2)
# Requirement already satisfied: wcwidth in /usr/local/envs/hw1/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.6.3->-r /content/MoCo-v2/condaenv.4c0oygt2.requirements.txt (line 11)) (0.2.5)
# Building wheels for collected packages: pandocfilters, pyrsistent, sklearn
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7992 sha256=078883eda21e972898c3737ce1ed65988cc8257e6346b106a40277f7b4e358c0
#   Stored in directory: /root/.cache/pip/wheels/fc/39/52/8d6f3cec1cca4ceb44d658427c35711b19d89dbc4914af657f
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp38-cp38-linux_x86_64.whl size=119651 sha256=fb3e001d6cd1be8ada6b5f1556d0671bb1ca12aa4bacfe677e40b15de1c6a523
#   Stored in directory: /root/.cache/pip/wheels/3d/22/08/7042eb6309c650c7b53615d5df5cc61f1ea9680e7edd3a08d2
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=78bcd278afe485d3d0c01d0548a78141fc7d99948075b2336c9adfc20f32f8cb
#   Stored in directory: /root/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built pandocfilters pyrsistent sklearn
# Installing collected packages: pyrsistent, attrs, pyparsing, jsonschema, webencodings, pycparser, packaging, nest-asyncio, nbformat, markupsafe, async-generator, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, jinja2, entrypoints, defusedxml, cffi, bleach, terminado, send2trash, prometheus-client, nbconvert, argon2-cffi, threadpoolctl, scipy, notebook, joblib, widgetsnbextension, scikit-learn, pytz, kiwisolver, jupyterlab-widgets, cycler, tqdm, sklearn, pandas, matplotlib, ipywidgets, h5py, dill
# Successfully installed argon2-cffi-20.1.0 async-generator-1.10 attrs-21.2.0 bleach-3.3.0 cffi-1.14.5 cycler-0.10.0 defusedxml-0.7.1 dill-0.3.3 entrypoints-0.3 h5py-3.2.1 ipywidgets-7.6.3 jinja2-3.0.1 joblib-1.0.1 jsonschema-3.2.0 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.0 kiwisolver-1.3.1 markupsafe-2.0.1 matplotlib-3.4.2 mistune-0.8.4 nbclient-0.5.3 nbconvert-6.0.7 nbformat-5.1.3 nest-asyncio-1.5.1 notebook-6.4.0 packaging-20.9 pandas-1.2.4 pandocfilters-1.4.3 prometheus-client-0.10.1 pycparser-2.20 pyparsing-2.4.7 pyrsistent-0.17.3 pytz-2021.1 scikit-learn-0.24.2 scipy-1.6.3 send2trash-1.5.0 sklearn-0.0 terminado-0.10.0 testpath-0.5.0 threadpoolctl-2.1.0 tqdm-4.61.0 webencodings-0.5.1 widgetsnbextension-3.5.1
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate hw1
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# # **Activate the Enivronment: hw1**

# %%
# To active this enironment, we use
# %%bash
source activate hw1
python

# python commands are ready to run within your environment
import sys
print("Python version")
print (sys.version)
# Out:
# Python version
# 3.8.10 (default, May 19 2021, 18:05:58)
# [GCC 7.3.0]

# %% [markdown]
# # **Download Dataset** & install other stuff

# %%
# Following Alex's GitHub Guide
# [Step 2.] Downloading Data
# !rm -rf data
# !python download_data.py
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz to data/imagenette2.tgz
# 1557161984it [00:31, 50095878.92it/s]

# %%
# !pip install sklearn
# !pip install pandas
#!conda install src
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 1.1 MB/s
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 116.8 MB/s
# Collecting scipy>=1.1.0
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.1 MB/s
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.20.3)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=fabdf2cb9b852bf587860163693ef343f2d6f10ada34061a19a5f02e644f2209
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 scipy-1.7.3 sklearn-0.0 threadpoolctl-3.1.0
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 4.8 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 104.2 MB/s
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/site-packages (from pandas) (1.20.3)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 117.4 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Installing collected packages: pytz, python-dateutil, pandas
# Successfully installed pandas-1.3.5 python-dateutil-2.8.2 pytz-2021.3

# %% [markdown]
# # **Pre-Training Starts Here**😳

# %%
# [Step 3.] Unsupervised Pre-training
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import os
import random
import numpy as np

import torch
import torch.nn as nn
import torchvision

from tqdm import tqdm

from src import arch
from src import utils
from config import cfg
from src import pytorch_utils as ptu

import warnings
warnings.filterwarnings("ignore")

# assert torch.cuda.is_available(), "no CUDA"


# In[2]:


print(cfg())


# In[3]:


if cfg.seed is not None:
    random.seed(cfg.seed)
    torch.random.manual_seed(cfg.seed)
    torch.manual_seed(cfg.seed)
    torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    print(torch.cuda.get_device_properties(device))


# In[4]:


print(cfg.moco.version)


# In[5]:


if cfg.moco.load is not None and os.path.exists(os.path.join(cfg.models_dir, cfg.moco.version, ptu.naming_scheme(cfg.moco.version, epoch=cfg.moco.load)) + '.pth'):
    checkpoint = ptu.load_model(version=cfg.moco.version, models_dir=cfg.models_dir, epoch=cfg.moco.load)
    if cfg.prints == 'display':
        display(checkpoint.log.sort_index(ascending=False).head(20))
    elif cfg.prints == 'print':
        print(checkpoint.log.sort_index(ascending=False).head(20))
else:
    model = arch.MoCo_v2(backbone=cfg.moco.backbone,
                         dim=cfg.moco.dim,
                         queue_size=cfg.moco.queue_size,
                         batch_size=cfg.moco.bs,
                         momentum=cfg.moco.model_momentum,
                         temperature=cfg.moco.temperature,
                         bias=cfg.moco.bias,
                         moco=True,
                         clf_hyperparams=cfg.moco.clf_kwargs,
                         seed=cfg.seed,
                         mlp=cfg.moco.mlp,
                        )

    optimizer = torch.optim.SGD([p for p in model.parameters() if p.requires_grad],
                                lr=cfg.moco.lr,
                                momentum=cfg.moco.optimizer_momentum,
                                weight_decay=cfg.moco.wd)

    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,
                                                              T_max=cfg.moco.epochs,
                                                              eta_min=cfg.moco.min_lr) if cfg.moco.cos else None

    checkpoint = utils.MyCheckpoint(version=cfg.moco.version,
                                    model=model,
                                    optimizer=optimizer,
                                    criterion=nn.CrossEntropyLoss().to(device),
                                    score=utils.accuracy_score,
                                    lr_scheduler=lr_scheduler,
                                    models_dir=cfg.models_dir,
                                    seed=cfg.seed,
                                    best_policy=cfg.moco.best_policy,
                                    save=cfg.save,
                                   )
    if cfg.save:
        with open(os.path.join(checkpoint.version_dir, 'config.txt'), 'w') as f:
            f.writelines(str(cfg))

ptu.params(checkpoint.model)


# In[7]:


train_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.moco.train_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
train_eval_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.moco.train_eval_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
val_dataset = utils.Dataset(os.path.join(cfg.data_path, 'val'), cfg.moco.val_eval_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size=checkpoint.model.batch_size,
                                           num_workers=cfg.num_workers,
                                           drop_last=True, shuffle=True, pin_memory=True)

train_eval_loader = torch.utils.data.DataLoader(train_eval_dataset,
                                                batch_size=checkpoint.model.batch_size,
                                                num_workers=cfg.num_workers,
                                                drop_last=True, shuffle=True, pin_memory=True)

val_loader = torch.utils.data.DataLoader(val_dataset,
                                         batch_size=checkpoint.model.batch_size,
                                         num_workers=cfg.num_workers,
                                         drop_last=True, shuffle=False, pin_memory=True)


# In[ ]:


checkpoint.train(train_loader=train_loader,
                 train_eval_loader=train_eval_loader,
                 val_loader=val_loader,
                 train_epochs=int(max(0, cfg.moco.epochs - checkpoint.get_log())),
                 optimizer_params=cfg.moco.optimizer_params,
                 prints=cfg.prints,
                 epochs_save=cfg.epochs_save,
                 epochs_evaluate_train=cfg.epochs_evaluate_train,
                 epochs_evaluate_validation=cfg.epochs_evaluate_validation,
                 device=device,
                 tqdm_bar=cfg.tqdm_bar,
                 save=cfg.save,
                 save_log=cfg.save_log,
                )


# In[ ]:


# import torchviz
# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=256, num_workers=0, drop_last=True, shuffle=True, pin_memory=True)
# for batch in train_loader:
#     (q_img, k_img), labels = batch
#     q_img = q_img.to(device)
#     k_img = k_img.to(device)
#     labels = labels.to(device)
#     model = checkpoint.model.to(device)
    
#     out = checkpoint.model(q_img, k_img, prints=True)
#     q, logits, zeros = out
#     print('q_img',  q_img.shape)
#     print('k_img',  k_img.shape)
#     print('labels', labels.shape)
#     print('logits', logits.shape)
#     print('zeros',  zeros.shape)
#     loss = nn.functional.cross_entropy(logits.float(), zeros.long())
#     print('loss',  loss)
#     break
# torchviz.make_dot(out, params=dict(model.named_parameters()))


# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# Out:
# {'moco': {'load': -1, 'wd': 0.0001, 'backbone': 'resnext50_32x4d', 'bs': 32, 'temperature': 0.2, 'queue_size': 8192, 'epochs': 40, 'optimizer_params': {}, 'optimizer_momentum': 0.9, 'lr': 0.03, 'min_lr': 5e-07, 'cos': True, 'best_policy': 'val_score', 'model_momentum': 0.999, 'dim': 128, 'mlp': True, 'bias': True, 'clf_kwargs': {'random_state': 42, 'max_iter': 10000}, 'train_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.2, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomApply(
#     p=0.8
#     ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[-0.1, 0.1])
# )
#     RandomGrayscale(p=0.2)
#     RandomApply(
#     p=0.5
#     GaussianBlur(0.1, 2.0)
# )
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'train_eval_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'val_eval_transforms': Compose(
#     Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'version': 'resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos'}, 'clf': {'load': -1, 'moco_epoch': 'best', 'epochs': 40, 'wd': 0.0, 'lr': 0.03, 'cos': True, 'optimizer_params': {}, 'version': 'resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos_epochbest_clf_wd0.0_cos', 'best_policy': 'val_score', 'bs': 32, 'optimizer_momentum': 0.9, 'min_lr': 5e-07, 'train_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'val_transforms': Compose(
#     Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )}, 'seed': None, 'data_path': 'data/imagenette2', 'models_dir': 'models', 'save': True, 'save_log': True, 'epochs_evaluate_train': 1, 'epochs_evaluate_validation': 1, 'num_workers': 2, 'epochs_save': None, 'tqdm_bar': False, 'preload_data': True, 'prints': 'print'}
# cpu
# resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos
#     train_time            timestamp  ...  nesterov  weight_decay
# 14  368.825923  17:47:37 08-03-2022  ...       0.0        0.0001
# 13  342.547283  17:21:21 08-03-2022  ...       0.0        0.0001
# 12  313.857144  16:52:39 08-03-2022  ...       0.0        0.0001
# 11  287.893876  16:26:41 08-03-2022  ...       0.0        0.0001
# 10  257.372713  15:56:10 08-03-2022  ...       0.0        0.0001
# 9   229.236420  15:28:02 08-03-2022  ...       0.0        0.0001
# 8   201.934324  15:00:44 08-03-2022  ...       0.0        0.0001
# 7   176.403848  14:35:12 08-03-2022  ...       0.0        0.0001
# 6   148.769552  14:07:34 08-03-2022  ...       0.0        0.0001
# 5   122.886146  13:41:41 08-03-2022  ...       0.0        0.0001
# 4    97.139053  13:15:56 08-03-2022  ...       0.0        0.0001
# 3    72.929959  12:37:29 08-03-2022  ...       0.0        0.0001
# 2    48.544734  12:13:06 08-03-2022  ...       0.0        0.0001
# 1    25.455831  11:50:01 08-03-2022  ...       0.0        0.0001
#
# [14 rows x 14 columns]
# Number of parameters 54877056 trainable 27438528
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-088900fc51f7> in <module>()
#     109
#     110
# --> 111 train_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.moco.train_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
#     112 train_eval_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.moco.train_eval_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
#     113 val_dataset = utils.Dataset(os.path.join(cfg.data_path, 'val'), cfg.moco.val_eval_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
#
# /content/MoCo-v2/src/utils.py in __init__(self, path, transforms, preload_data, tqdm_bar)
#     120                 pbar = self.torchvision_dataset
#     121
# --> 122             for image, label in pbar:
#     123                 self.images.append(image)
#     124                 self.labels.append(label)
#
# /usr/local/lib/python3.7/site-packages/torchvision/datasets/folder.py in __getitem__(self, index)
#     230         """
#     231         path, target = self.samples[index]
# --> 232         sample = self.loader(path)
#     233         if self.transform is not None:
#     234             sample = self.transform(sample)
#
# /usr/local/lib/python3.7/site-packages/torchvision/datasets/folder.py in default_loader(path)
#     267         return accimage_loader(path)
#     268     else:
# --> 269         return pil_loader(path)
#     270
#     271
#
# /usr/local/lib/python3.7/site-packages/torchvision/datasets/folder.py in pil_loader(path)
#     249     with open(path, 'rb') as f:
#     250         img = Image.open(f)
# --> 251         return img.convert('RGB')
#     252
#     253
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     899         """
#     900
# --> 901         self.load()
#     902
#     903         if not mode and self.mode == "P":
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py in load(self)
#     205                     self.map = None
#     206
# --> 207         self.load_prepare()
#     208         err_code = -3  # initialize to unknown error
#     209         if not self.map:
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py in load_prepare(self)
#     275         # create image memory if necessary
#     276         if not self.im or self.im.mode != self.mode or self.im.size != self.size:
# --> 277             self.im = Image.core.new(self.mode, self.size)
#     278         # create palette (optional)
#     279         if self.mode == "P":
#
# KeyboardInterrupt:

# %% [markdown]
# # **Linear Classification starts next** 😨

# %%
# Running Linear Classification

#!/usr/bin/env python
# coding: utf-8

# In[1]:


import os
import random
import numpy as np

import torch
import torch.nn as nn
import torchvision

from tqdm import tqdm

from src import arch
from src import utils
from config import cfg
from src import pytorch_utils as ptu

import warnings
warnings.filterwarnings("ignore")

# assert torch.cuda.is_available(), "no CUDA"


# In[2]:


print(cfg())


# In[3]:


if cfg.seed is not None:
    random.seed(cfg.seed)
    torch.random.manual_seed(cfg.seed)
    torch.manual_seed(cfg.seed)
    torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    print(torch.cuda.get_device_properties(device))


# In[4]:


print(cfg.moco.version)


# In[5]:


print(cfg.clf.version)


# In[6]:


if cfg.clf.load is not None and os.path.exists(os.path.join(cfg.models_dir, cfg.clf.version, ptu.naming_scheme(cfg.clf.version, epoch=cfg.clf.load)) + '.pth'):
    checkpoint = ptu.load_model(version=cfg.clf.version, models_dir=cfg.models_dir, epoch=cfg.clf.load)
    if cfg.prints == 'display':
        display(checkpoint.log.sort_index(ascending=False).head(20))
    elif cfg.prints == 'print':
        print(checkpoint.log.sort_index(ascending=False).head(20))
else:
    moco_checkpoint = ptu.load_model(version=cfg.moco.version, models_dir=cfg.models_dir, epoch=cfg.clf.moco_epoch)
    model = moco_checkpoint.model
    model.end_moco_phase()
    if cfg.prints == 'display':
        display(moco_checkpoint.log.sort_index(ascending=False).head(5))
    elif cfg.prints == 'print':
        print(moco_checkpoint.log.sort_index(ascending=False).head(5))

    optimizer = torch.optim.SGD([p for p in model.parameters() if p.requires_grad],
                                lr=cfg.clf.lr,
                                momentum=cfg.clf.optimizer_momentum,
                                weight_decay=cfg.clf.wd)

    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,
                                                              T_max=cfg.clf.epochs,
                                                              eta_min=cfg.clf.min_lr) if cfg.clf.cos else None

    checkpoint = utils.MyCheckpoint(version=cfg.clf.version,
                                    model=model,
                                    optimizer=optimizer,
                                    criterion=nn.CrossEntropyLoss().to(device),
                                    score=utils.accuracy_score,
                                    lr_scheduler=lr_scheduler,
                                    models_dir=cfg.models_dir,
                                    seed=cfg.seed,
                                    best_policy=cfg.clf.best_policy,
                                    save=cfg.save,
                                   )

    checkpoint.moco_log = moco_checkpoint.log
    checkpoint.moco_train_batch_log = moco_checkpoint.train_loss_log

    if cfg.save:
        with open(os.path.join(checkpoint.version_dir, 'config.txt'), 'w') as f:
            f.writelines(str(cfg))

ptu.params(checkpoint.model)
ptu.params(checkpoint.model.q_encoder.fc)


# In[8]:


train_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.clf.train_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
val_dataset = utils.Dataset(os.path.join(cfg.data_path, 'val'), cfg.clf.val_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size=checkpoint.model.batch_size,
                                           num_workers=cfg.num_workers,
                                           drop_last=True, shuffle=True, pin_memory=True)

val_loader = torch.utils.data.DataLoader(val_dataset,
                                         batch_size=checkpoint.model.batch_size,
                                         num_workers=cfg.num_workers,
                                         drop_last=True, shuffle=False, pin_memory=True)


# In[ ]:


checkpoint.train(train_loader=train_loader,
                 val_loader=val_loader,
                 train_epochs=int(max(0, cfg.clf.epochs - checkpoint.get_log())),
                 optimizer_params=cfg.clf.optimizer_params,
                 prints=cfg.prints,
                 epochs_save=cfg.epochs_save,
                 epochs_evaluate_train=cfg.epochs_evaluate_train,
                 epochs_evaluate_validation=cfg.epochs_evaluate_validation,
                 device=device,
                 tqdm_bar=cfg.tqdm_bar,
                 save=cfg.save,
                 save_log=cfg.save_log,
                )


# In[ ]:


# import torchviz
# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, num_workers=0, drop_last=True, shuffle=True, pin_memory=True)
# for batch in train_loader:
#     img, labels = batch
#     img = img.to(device)
#     labels = labels.to(device)
#     model = model.to(device)
#     out = model(img, prints=True)
#     print('img',  img.shape)
#     print('labels', labels.shape)
#     print('out', out.shape)
#     loss = nn.functional.cross_entropy(out.float(), labels.long())
#     print('loss',  loss)
#     break
# torchviz.make_dot(out, params=dict(model.named_parameters()))


# In[ ]:
# In[ ]:
# In[ ]:
# In[ ]:
# Out:
# {'moco': {'load': -1, 'wd': 0.0001, 'backbone': 'resnext50_32x4d', 'bs': 32, 'temperature': 0.2, 'queue_size': 8192, 'epochs': 40, 'optimizer_params': {}, 'optimizer_momentum': 0.9, 'lr': 0.03, 'min_lr': 5e-07, 'cos': True, 'best_policy': 'val_score', 'model_momentum': 0.999, 'dim': 128, 'mlp': True, 'bias': True, 'clf_kwargs': {'random_state': 42, 'max_iter': 10000}, 'train_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.2, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomApply(
#     p=0.8
#     ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=[-0.1, 0.1])
# )
#     RandomGrayscale(p=0.2)
#     RandomApply(
#     p=0.5
#     GaussianBlur(0.1, 2.0)
# )
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'train_eval_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'val_eval_transforms': Compose(
#     Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'version': 'resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos'}, 'clf': {'load': -1, 'moco_epoch': 'best', 'epochs': 40, 'wd': 0.0, 'lr': 0.03, 'cos': True, 'optimizer_params': {}, 'version': 'resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos_epochbest_clf_wd0.0_cos', 'best_policy': 'val_score', 'bs': 32, 'optimizer_momentum': 0.9, 'min_lr': 5e-07, 'train_transforms': Compose(
#     RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ), 'val_transforms': Compose(
#     Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )}, 'seed': None, 'data_path': 'data/imagenette2', 'models_dir': 'models', 'save': True, 'save_log': True, 'epochs_evaluate_train': 1, 'epochs_evaluate_validation': 1, 'num_workers': 2, 'epochs_save': None, 'tqdm_bar': False, 'preload_data': True, 'prints': 'print'}
# cpu
# resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos
# resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos_epochbest_clf_wd0.0_cos
#     train_time            timestamp  ...  nesterov  weight_decay
# 14  368.825923  17:47:37 08-03-2022  ...       0.0        0.0001
# 13  342.547283  17:21:21 08-03-2022  ...       0.0        0.0001
# 12  313.857144  16:52:39 08-03-2022  ...       0.0        0.0001
# 11  287.893876  16:26:41 08-03-2022  ...       0.0        0.0001
# 10  257.372713  15:56:10 08-03-2022  ...       0.0        0.0001
#
# [5 rows x 14 columns]
# Number of parameters 23000394 trainable 20490
# Number of parameters 20490 trainable 20490
# epoch   1/ 40 | train_loss 14.76741 | val_loss 14.29610 | train_score 0.29576 | val_score 0.31071 | train_time   6.34 min | best
# epoch   2/ 40 | train_loss 18.85641 | val_loss 17.53201 | train_score 0.22722 | val_score 0.22285 | train_time  12.82 min
# epoch   3/ 40 | train_loss 16.26316 | val_loss 14.94344 | train_score 0.33199 | val_score 0.35579 | train_time  19.43 min | best
# epoch   4/ 40 | train_loss 15.82573 | val_loss 15.52893 | train_score 0.32129 | val_score 0.32044 | train_time  25.81 min
# epoch   5/ 40 | train_loss 10.62405 | val_loss 9.92607 | train_score 0.38506 | val_score 0.40984 | train_time  32.23 min | best
# epoch   6/ 40 | train_loss 21.35711 | val_loss 22.02988 | train_score 0.31112 | val_score 0.31583 | train_time  38.61 min
# epoch   7/ 40 | train_loss 12.62717 | val_loss 11.82691 | train_score 0.36515 | val_score 0.39088 | train_time  45.05 min
# epoch   8/ 40 | train_loss 11.88454 | val_loss 10.69904 | train_score 0.36155 | val_score 0.39703 | train_time  51.48 min
# epoch   9/ 40 | train_loss 10.16704 | val_loss 8.78893 | train_score 0.39153 | val_score 0.43596 | train_time  58.07 min | best
# epoch  10/ 40 | train_loss 12.48907 | val_loss 12.54076 | train_score 0.36186 | val_score 0.36014 | train_time  64.90 min
# epoch  11/ 40 | train_loss 12.93549 | val_loss 12.69368 | train_score 0.36536 | val_score 0.39088 | train_time  71.67 min
# epoch  12/ 40 | train_loss 16.13630 | val_loss 14.57923 | train_score 0.37002 | val_score 0.39857 | train_time  78.46 min
# epoch  13/ 40 | train_loss 15.31065 | val_loss 14.02434 | train_score 0.32606 | val_score 0.35118 | train_time  85.07 min
# epoch  14/ 40 | train_loss 9.96108 | val_loss 9.61085 | train_score 0.41229 | val_score 0.43673 | train_time  91.66 min | best
# epoch  15/ 40 | train_loss 15.09920 | val_loss 13.93235 | train_score 0.25413 | val_score 0.28612 | train_time  98.09 min
# epoch  16/ 40 | train_loss 12.11433 | val_loss 12.27693 | train_score 0.37871 | val_score 0.39344 | train_time 104.57 min
# epoch  17/ 40 | train_loss 15.23089 | val_loss 14.81087 | train_score 0.32754 | val_score 0.34529 | train_time 111.06 min
# epoch  18/ 40 | train_loss 9.18334 | val_loss 8.18389 | train_score 0.33422 | val_score 0.37731 | train_time 117.53 min
# epoch  19/ 40 | train_loss 8.01304 | val_loss 7.21262 | train_score 0.40911 | val_score 0.45005 | train_time 124.01 min | best
# epoch  20/ 40 | train_loss 10.55834 | val_loss 10.29943 | train_score 0.33856 | val_score 0.36475 | train_time 130.47 min
# epoch  21/ 40 | train_loss 9.35275 | val_loss 9.12447 | train_score 0.34290 | val_score 0.36834 | train_time 136.95 min
# epoch  22/ 40 | train_loss 10.23637 | val_loss 10.10264 | train_score 0.40085 | val_score 0.42623 | train_time 143.46 min
# epoch  23/ 40 | train_loss 8.46136 | val_loss 8.65301 | train_score 0.45657 | val_score 0.46926 | train_time 149.89 min | best
# epoch  24/ 40 | train_loss 5.62743 | val_loss 4.90893 | train_score 0.44629 | val_score 0.49308 | train_time 156.35 min | best
# epoch  25/ 40 | train_loss 5.61649 | val_loss 5.22807 | train_score 0.43422 | val_score 0.44877 | train_time 162.80 min
# epoch  26/ 40 | train_loss 6.57917 | val_loss 6.42819 | train_score 0.38750 | val_score 0.40830 | train_time 169.28 min
# epoch  27/ 40 | train_loss 4.70055 | val_loss 4.13712 | train_score 0.43443 | val_score 0.48514 | train_time 175.77 min
# epoch  28/ 40 | train_loss 4.76628 | val_loss 4.22005 | train_score 0.42172 | val_score 0.47362 | train_time 182.27 min
# epoch  29/ 40 | train_loss 4.03804 | val_loss 3.82338 | train_score 0.50900 | val_score 0.53842 | train_time 188.72 min | best
# epoch  30/ 40 | train_loss 3.32212 | val_loss 2.95421 | train_score 0.51409 | val_score 0.54329 | train_time 195.30 min | best
# epoch  31/ 40 | train_loss 3.06349 | val_loss 2.84353 | train_score 0.52182 | val_score 0.56250 | train_time 202.21 min | best
# epoch  32/ 40 | train_loss 3.28461 | val_loss 2.88798 | train_score 0.49470 | val_score 0.54303 | train_time 209.08 min
# epoch  33/ 40 | train_loss 3.04626 | val_loss 2.78733 | train_score 0.51345 | val_score 0.55866 | train_time 215.76 min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f21f63bedde4> in <module>()
#     143                  tqdm_bar=cfg.tqdm_bar,
#     144                  save=cfg.save,
# --> 145                  save_log=cfg.save_log,
#     146                 )
#     147
#
# /content/MoCo-v2/src/pytorch_utils/checkpoint.py in train(self, train_loader, train_eval_loader, val_loader, train_epochs, optimizer_params, prints, callback_kwargs, device, save, epochs_save, epochs_evaluate_train, epochs_evaluate_validation, tqdm_bar, max_iterations_train, max_iterations_val, save_log, *args, **kwargs)
#     566                 self.train_mode = False
#     567                 if epochs_evaluate_train is not None and epoch % epochs_evaluate_train == 0:
# --> 568                     train_loss, train_score, train_results = self.run(device, train_eval_loader, epoch, train=True, tqdm_bar=tqdm_bar, max_iterations=max_iterations_val, *args, **kwargs)
#     569
#     570                 if val_loader is not None and epochs_evaluate_validation is not None and epoch % epochs_evaluate_validation == 0:
#
# /content/MoCo-v2/src/pytorch_utils/checkpoint.py in run(self, *args, **kwargs)
#     160     def run(self, *args, **kwargs):
#     161         """ overrideable run function, for example see _run """
# --> 162         return self._run(*args, **kwargs)
#     163
#     164     def batch_pass(self, *args, **kwargs):
#
# /content/MoCo-v2/src/pytorch_utils/checkpoint.py in _run(self, device, loader, epoch, train, tqdm_bar, max_iterations, *args, **kwargs)
#     428         for i, batch in enumerate(loader):
#     429             # pass batch through model, calculate loss and predict
# --> 430             loss, batch_results, pbar_postfix = self.batch_pass(device, batch, train=train, *args, **kwargs)
#     431
#     432             if tqdm_bar:
#
# /content/MoCo-v2/src/utils.py in batch_pass(self, device, batch, train, *args, **kwargs)
#      60             self.batch_size = img.shape[0]
#      61
# ---> 62             out = self.model(img)
#      63
#      64             loss = self.criterion(out.float(), labels.long())
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/MoCo-v2/src/arch.py in forward(self, prints, *args)
#     142             return self.moco_forward(*args, prints=prints)
#     143         else:
# --> 144             return self.clf_forward(*args, prints=prints)
#     145
#     146     def moco_forward(self, q, k, prints=False):
#
# /content/MoCo-v2/src/arch.py in clf_forward(self, x, prints)
#     186         print('x in', x.shape) if prints else None
#     187
# --> 188         x = self.q_encoder(x)
#     189         print('q_encoder(x)', x.shape) if prints else None
#     190
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     247
#     248     def forward(self, x: Tensor) -> Tensor:
# --> 249         return self._forward_impl(x)
#     250
#     251
#
# /usr/local/lib/python3.7/site-packages/torchvision/models/resnet.py in _forward_impl(self, x)
#     235         x = self.maxpool(x)
#     236
# --> 237         x = self.layer1(x)
#     238         x = self.layer2(x)
#     239         x = self.layer3(x)
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     122         identity = x
#     123
# --> 124         out = self.conv1(x)
#     125         out = self.bn1(out)
#     126         out = self.relu(out)
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             _pair(0), self.dilation, self.groups)
#     442         return F.conv2d(input, weight, bias, self.stride,
# --> 443                         self.padding, self.dilation, self.groups)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import os
import random
import numpy as np

import torch
import torch.nn as nn
import torchvision

from tqdm import tqdm

from src import arch
from src import utils
from config import cfg
from src import pytorch_utils as ptu

import warnings
warnings.filterwarnings("ignore")

# assert torch.cuda.is_available(), "no CUDA"


# In[2]:


cfg.seed = 42
random.seed(cfg.seed)
torch.random.manual_seed(cfg.seed)
torch.manual_seed(cfg.seed)
torch.backends.cudnn.deterministic = True
cfg.num_workers = 0


# In[3]:


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
if device.type == 'cuda':
    torch.backends.cudnn.benchmark = True
    print(torch.cuda.get_device_properties(device))


# In[4]:


print('clf.version\n', cfg.clf.version)


# In[5]:


cfg.clf.load = 'best'
cfg.preload_data = False
# cfg.prints = 'display'
# cfg.tqdm_bar = True


# In[6]:


if cfg.clf.load is not None and os.path.exists(os.path.join(cfg.models_dir, cfg.clf.version, ptu.naming_scheme(cfg.clf.version, epoch=cfg.clf.load)) + '.pth'):
    checkpoint = ptu.load_model(version=cfg.clf.version, models_dir=cfg.models_dir, epoch=cfg.clf.load)


# In[7]:


train_dataset = utils.Dataset(os.path.join(cfg.data_path, 'train'), cfg.clf.train_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)
val_dataset = utils.Dataset(os.path.join(cfg.data_path, 'val'), cfg.clf.val_transforms, preload_data=cfg.preload_data, tqdm_bar=cfg.tqdm_bar)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                           batch_size=checkpoint.model.batch_size,
                                           num_workers=cfg.num_workers,
                                           drop_last=True, shuffle=True, pin_memory=True)

val_loader = torch.utils.data.DataLoader(val_dataset,
                                         batch_size=checkpoint.model.batch_size,
                                         num_workers=cfg.num_workers,
                                         drop_last=True, shuffle=False, pin_memory=True)


# In[8]:


train_loss, train_score, train_results = checkpoint.evaluate(train_loader,
                                                             device=device,
                                                             tqdm_bar=cfg.tqdm_bar)


# In[9]:


val_loss, val_score, val_results = checkpoint.evaluate(val_loader,
                                                       device=device,
                                                       tqdm_bar=cfg.tqdm_bar)


# In[10]:


print(f'train | loss: {train_loss:.4f} | top-1 acc: {train_score:.6f}')
print(f'val   | loss: {val_loss:.4f} | top-1 acc: {val_score:.6f}')


# In[ ]:





# In[ ]:





# In[ ]:





# In[ ]:
# Out:
# cpu
# clf.version
#  resnext50_32x4d_bs32_queue8192_wd0.0001_t0.2_cos_epochbest_clf_wd0.0_cos
# train | loss: 3.0408 | top-1 acc: 0.525424
# val   | loss: 2.8435 | top-1 acc: 0.562500
